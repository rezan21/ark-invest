# %%
# process ark-trades csvs

import concurrent.futures
import pandas as pd
from pathlib import Path

# %%
# read files parallel
files = list(Path("./trades/").glob("*.csv"))

def parallel_read(f):
    try:
        df = pd.read_csv(f, header=3,
                         usecols=["FUND", "Date", "Direction", "Ticker", "CUSIP", "Name", "Shares", "% of ETF"]
                        )
        df.columns = df.columns.map(lambda x: x.lower())
        return df
    except Exception as err:
        print(err)

df = [] # list of dfs
with concurrent.futures.ThreadPoolExecutor(max_workers=4) as executor:
    df.extend(executor.map(parallel_read, files))
df = pd.concat(df).reset_index(drop=True)
df
# Out:
#      fund        date direction ticker      cusip  \
# 0    ARKF  2021-02-09       Buy   PYPL  70450Y103
# 1    ARKF  2021-02-09      Sell   LSPD  53227R106
# 2    ARKG  2021-02-09       Buy    NVS  66987V109
# 3    ARKG  2021-02-09       Buy  RHHBY  771195104
# 4    ARKG  2021-02-09       Buy   REGN  75886F107
# ..    ...         ...       ...    ...        ...
# 197  ARKW  2021-02-08       Buy      U  91332U101
# 198  ARKW  2021-02-08      Sell   PINS  72352L106
# 199  ARKW  2021-02-08      Sell  TCEHY  88032Q109
# 200  ARKW  2021-02-08      Sell    API  00851L103
# 201  ARKW  2021-02-08      Sell     SE  81141R100
#
#                               name    shares  % of etf
# 0              PAYPAL HOLDINGS INC   20600.0    0.1671
# 1               LIGHTSPEED POS INC   44100.0    0.0923
# 2                      NOVARTIS AG  426773.0    0.3095
# 3                 ROCHE HOLDING AG  200400.0    0.0697
# 4    REGENERON PHARMACEUTICALS INC   28723.0    0.1131
# ..                             ...       ...       ...
# 197             UNITY SOFTWARE INC  183300.0    0.4878
# 198                  PINTEREST INC  329200.0    0.3256
# 199           TENCENT HOLDINGS LTD  196000.0    0.2318
# 200                      AGORA INC  157993.0    0.1952
# 201                        SEA LTD  101800.0    0.3317
#
# [202 rows x 8 columns]

# %%
df["date"] = pd.to_datetime(df["date"])
df.sort_values(["date", "ticker"], inplace=True)
df = df.dropna().reset_index(drop=True)
df
# Out:
#      fund       date direction ticker      cusip  \
# 0    ARKW 2021-02-01      Sell    API  00851L103
# 1    ARKQ 2021-02-01      Sell   AVAV    8073108
# 2    ARKK 2021-02-01       Buy   BEAM  07373V105
# 3    ARKW 2021-02-01       Buy   BEKE  482497104
# 4    ARKQ 2021-02-01      Sell  BYDDY  05606L100
# ..    ...        ...       ...    ...        ...
# 196  ARKG 2021-02-11      Sell   PACB  69404D108
# 197  ARKF 2021-02-11       Buy   PYPL  70450Y103
# 198  ARKG 2021-02-11       Buy  RHHBY  771195104
# 199  ARKW 2021-02-11       Buy   SHOP  82509L107
# 200  ARKK 2021-02-11      Sell   SSYS  M85548101
#
#                                       name    shares  % of etf
# 0                                AGORA INC   54100.0    0.0577
# 1                        AEROVIRONMENT INC    6132.0    0.0241
# 2                    BEAM THERAPEUTICS INC   58218.0    0.0241
# 3                          KE HOLDINGS INC  110900.0    0.0986
# 4                               BYD CO LTD   31503.0    0.0671
# ..                                     ...       ...       ...
# 196  PACIFIC BIOSCIENCES OF CALIFORNIA INC  667121.0    0.2699
# 197                    PAYPAL HOLDINGS INC   17056.0    0.1228
# 198                       ROCHE HOLDING AG  244902.0    0.0844
# 199                            SHOPIFY INC    9370.0    0.1549
# 200                          STRATASYS LTD   88371.0    0.0165
#
# [201 rows x 8 columns]

# %%
df.to_csv("./local/ark_trades_feb.csv", index=False)
