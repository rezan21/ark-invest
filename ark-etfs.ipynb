# %%
from pathlib import Path

import pandas as pd

# %%
ETF = "ARKG"
etf_his_files = list(Path(f"./ETFs/{ETF}/").glob("*.csv"))
df = pd.concat([pd.read_csv(f).dropna() for f in etf_his_files])
df
# Out:
#          date  fund                       company ticker      cusip  \
# 0   1/29/2021  ARKG            TELADOC HEALTH INC   TDOC  87918A105
# 1   1/29/2021  ARKG         TWIST BIOSCIENCE CORP   TWST  90184D100
# 2   1/29/2021  ARKG  PACIFIC BIOSCIENCES OF CALIF   PACB  69404D108
# 3   1/29/2021  ARKG           EXACT SCIENCES CORP   EXAS  30063P105
# 4   1/29/2021  ARKG     REGENERON PHARMACEUTICALS   REGN  75886F107
# ..        ...   ...                           ...    ...        ...
# 48  1/26/2021  ARKG               908 DEVICES INC   MASS  65443P102
# 49  1/26/2021  ARKG                   EVOGENE LTD   EVGN  M4119S104
# 50  1/26/2021  ARKG    PLURISTEM THERAPEUTICS INC   PSTI  72940R300
# 51  1/26/2021  ARKG          1LIFE HEALTHCARE INC   ONEM  68269G107
# 52  1/26/2021  ARKG         ORGANOVO HOLDINGS INC  ONVO   68620A203
#
#         shares  market value($)  weight(%)
# 0    3238661.0     8.544559e+08       7.97
# 1    3652580.0     6.009955e+08       5.61
# ...

# %%
df["date"] = pd.to_datetime(df["date"], format="%m/%d/%Y")
df.sort_values(["ticker", "date"], inplace=True)
df
# Out:
#          date  fund                     company ticker      cusip     shares  \
# 19 2021-01-25  ARKG                ACCOLADE INC   ACCD  00437E102  3851588.0
# 19 2021-01-26  ARKG                ACCOLADE INC   ACCD  00437E102  3862508.0
# 18 2021-01-29  ARKG                ACCOLADE INC   ACCD  00437E102  4096075.0
# 33 2021-01-25  ARKG    ADAPTIVE BIOTECHNOLOGIES   ADPT  00650F109  1982588.0
# 33 2021-01-26  ARKG    ADAPTIVE BIOTECHNOLOGIES   ADPT  00650F109  1988210.0
# ..        ...   ...                         ...    ...        ...        ...
# 24 2021-01-26  ARKG   VEEVA SYSTEMS INC-CLASS A   VEEV  922475108   599190.0
# 24 2021-01-29  ARKG   VEEVA SYSTEMS INC-CLASS A   VEEV  922475108   592422.0
# 8  2021-01-25  ARKG  VERTEX PHARMACEUTICALS INC   VRTX  92532F100  1622680.0
# 8  2021-01-26  ARKG  VERTEX PHARMACEUTICALS INC   VRTX  92532F100  1627282.0
# 8  2021-01-29  ARKG  VERTEX PHARMACEUTICALS INC   VRTX  92532F100  1608874.0
#
#     market value($)  weight(%)
# ...

# %%
gg = df.groupby("ticker")
for g in gg.groups:
    gdf = gg.get_group(g)

# %%
gdf
# Out:
#         date  fund                     company ticker      cusip     shares  \
# 8 2021-01-25  ARKG  VERTEX PHARMACEUTICALS INC   VRTX  92532F100  1622680.0
# 8 2021-01-26  ARKG  VERTEX PHARMACEUTICALS INC   VRTX  92532F100  1627282.0
# 8 2021-01-29  ARKG  VERTEX PHARMACEUTICALS INC   VRTX  92532F100  1608874.0
#
#    market value($)  weight(%)
# 8     3.915689e+08       3.31
# 8     3.867073e+08       3.43
# 8     3.685609e+08       3.44

# %%
t = df[df["date"]=="2021-01-29"]

# %%
t["market value($)"].mean()
# Out:
# 201873676.15132076
